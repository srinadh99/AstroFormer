# %% [markdown]
# ## MargFormer - Experiment2 - Star-Galaxy-Quasar Classification
#
# ## Star-Galaxy-Quasar Classification (Experiment 2) using Vision Transformer (ViT, Linformer) Model with CLS token derived uisng the Photometric Features. Query is defined using only photometry data in the Cross-Attention.

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
np.random.seed(69)
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
sns.set()
# from tqdm.notebook 
import tqdm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import time
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from linformer import LinformerCA, Linformer
from vit_pytorch.efficient_new import ViT

# %% [markdown]
# #### 1. Load and extract the dataset

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

# idx_drop = np.where(y=="QSO")[0]
# X = np.delete(X,idx_drop,axis=0)
# dnnx = np.delete(dnnx,idx_drop,axis=0)
# y = np.delete(y,idx_drop,axis=0)
# objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)
# Out:
# ['GALAXY' 'QSO' 'STAR']

# %%
zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.1,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1111111, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)
# Out:
# The shape of the Train data is: (119996, 5, 32, 32)
# The shape of the Validation data is: (15000, 5, 32, 32)
# The shape of the Test data is: (15000, 5, 32, 32)

# %%
def get_metrics(y_pred, y_test, labels, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print(f"Labels are: {labels}")
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

    return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData(Dataset):
    def __init__(self, x1, x2, y, transform=None):
        self.n_samples = x2.shape[0]
        self.x1 = torch.tensor(x1, dtype=torch.float32)
        self.x2 = torch.tensor(x2, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs_pf, inputs_imgs, targets = self.x1[i], self.x2[i], self.y[i]
        
        if self.transform:
            inputs_pf = inputs_pf
            inputs_imgs = self.transform(inputs_imgs)

        return inputs_pf, inputs_imgs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
train_dataset = SGData(dnnx_train, X_train, y_train, transform=image_transform)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True, num_workers=8)
val_dataset = SGData(dnnx_val, X_val, y_val, transform=image_transform)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False, num_workers=4)
test_dataset = SGData(dnnx_test, X_test, y_test, transform=None)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=4)

# %% [markdown]
# #### 2. Initialize or Define the Model

# %%
# Initialize the PyTorch model
n_classes = 3
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
in_channels = X_train.shape[1]

PATCH_SIZE = 4
DEPTH = 12
HIDDEN_DIM = 64
K_DIM = 64
NUM_HEADS = 8

LR = 1e-3
STEP_SIZE = 5
GAMMA = 0.9

LIN_DROPOUT = 0.1

seq_len = int((32/PATCH_SIZE)**2) + 1

## Linformer
lin = LinformerCA(dim=HIDDEN_DIM, seq_len=seq_len, depth=DEPTH, k=K_DIM, heads=NUM_HEADS,
                dim_head=None, one_kv_head=False, share_kv=False, reversible=False, dropout=LIN_DROPOUT)

## Vision Transformer
model = ViT(image_size=32, patch_size=PATCH_SIZE, num_classes=n_classes, dim=HIDDEN_DIM, transformer=lin, pool='cls', channels=in_channels).to(device)
# Out:
# cuda:0

# %% [markdown]
# #### 3. Training the model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 300
epoch1 =0
print('\n')
for epoch in range(epochs):
    epoch1+=1
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x1, batch_x2, batch_y in train_loader:
        batch_x1 = batch_x1.to(device)
        batch_x2 = batch_x2.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = model(batch_x1, batch_x2)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x1, batch_x2, batch_y in val_loader:
            batch_x1 = batch_x1.to(device)
            batch_x2 = batch_x2.to(device)
            batch_y = batch_y.to(device)
            output = model(batch_x1, batch_x2)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = model.state_dict()  # Store the current best model state
        torch.save(best_model_state, "Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Model.pth")
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Accuracy.png")
# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Loss.png")
# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/300] - Train Loss: 0.8129, Train Accuracy: 0.5971, Validation Loss: 0.5582, Validation Accuracy: 0.7466
# Epoch [2/300] - Train Loss: 0.5319, Train Accuracy: 0.7643, Validation Loss: 0.4932, Validation Accuracy: 0.7827
# Epoch [3/300] - Train Loss: 0.4739, Train Accuracy: 0.7949, Validation Loss: 0.4465, Validation Accuracy: 0.8100
# Epoch [4/300] - Train Loss: 0.4471, Train Accuracy: 0.8070, Validation Loss: 0.4355, Validation Accuracy: 0.8191
# Epoch [5/300] - Train Loss: 0.4281, Train Accuracy: 0.8181, Validation Loss: 0.4135, Validation Accuracy: 0.8221
# Epoch [6/300] - Train Loss: 0.4166, Train Accuracy: 0.8235, Validation Loss: 0.4063, Validation Accuracy: 0.8260
# Epoch [7/300] - Train Loss: 0.4055, Train Accuracy: 0.8290, Validation Loss: 0.3892, Validation Accuracy: 0.8331
# Epoch [8/300] - Train Loss: 0.3966, Train Accuracy: 0.8322, Validation Loss: 0.4080, Validation Accuracy: 0.8227
# Epoch [9/300] - Train Loss: 0.3904, Train Accuracy: 0.8347, Validation Loss: 0.3956, Validation Accuracy: 0.8319
# Epoch [10/300] - Train Loss: 0.3848, Train Accuracy: 0.8363, Validation Loss: 0.3734, Validation Accuracy: 0.8400
# Epoch [11/300] - Train Loss: 0.3833, Train Accuracy: 0.8381, Validation Loss: 0.3820, Validation Accuracy: 0.8341
# Epoch [12/300] - Train Loss: 0.3733, Train Accuracy: 0.8418, Validation Loss: 0.3670, Validation Accuracy: 0.8434
# Epoch [13/300] - Train Loss: 0.3719, Train Accuracy: 0.8431, Validation Loss: 0.3669, Validation Accuracy: 0.8437
# Epoch [14/300] - Train Loss: 0.3678, Train Accuracy: 0.8441, Validation Loss: 0.3615, Validation Accuracy: 0.8423
# Epoch [15/300] - Train Loss: 0.3674, Train Accuracy: 0.8448, Validation Loss: 0.3659, Validation Accuracy: 0.8415
# Epoch [16/300] - Train Loss: 0.3629, Train Accuracy: 0.8472, Validation Loss: 0.3596, Validation Accuracy: 0.8453
# Epoch [17/300] - Train Loss: 0.3605, Train Accuracy: 0.8484, Validation Loss: 0.3582, Validation Accuracy: 0.8490
# Epoch [18/300] - Train Loss: 0.3611, Train Accuracy: 0.8475, Validation Loss: 0.3490, Validation Accuracy: 0.8489
# Epoch [19/300] - Train Loss: 0.3585, Train Accuracy: 0.8494, Validation Loss: 0.3528, Validation Accuracy: 0.8489
# Epoch [20/300] - Train Loss: 0.3586, Train Accuracy: 0.8479, Validation Loss: 0.3487, Validation Accuracy: 0.8466
# Epoch [21/300] - Train Loss: 0.3552, Train Accuracy: 0.8505, Validation Loss: 0.3617, Validation Accuracy: 0.8451
# Epoch [22/300] - Train Loss: 0.3532, Train Accuracy: 0.8513, Validation Loss: 0.3546, Validation Accuracy: 0.8494
# Epoch [23/300] - Train Loss: 0.3503, Train Accuracy: 0.8529, Validation Loss: 0.3438, Validation Accuracy: 0.8542
# Epoch [24/300] - Train Loss: 0.3509, Train Accuracy: 0.8533, Validation Loss: 0.3488, Validation Accuracy: 0.8507
# Epoch [25/300] - Train Loss: 0.3504, Train Accuracy: 0.8528, Validation Loss: 0.3429, Validation Accuracy: 0.8535
# Epoch [26/300] - Train Loss: 0.3451, Train Accuracy: 0.8544, Validation Loss: 0.3478, Validation Accuracy: 0.8547
# Epoch [27/300] - Train Loss: 0.3462, Train Accuracy: 0.8542, Validation Loss: 0.3451, Validation Accuracy: 0.8520
# Epoch [28/300] - Train Loss: 0.3451, Train Accuracy: 0.8539, Validation Loss: 0.3406, Validation Accuracy: 0.8524
# Epoch [29/300] - Train Loss: 0.3428, Train Accuracy: 0.8551, Validation Loss: 0.3402, Validation Accuracy: 0.8551
# Epoch [30/300] - Train Loss: 0.3428, Train Accuracy: 0.8549, Validation Loss: 0.3397, Validation Accuracy: 0.8547
# Epoch [31/300] - Train Loss: 0.3421, Train Accuracy: 0.8558, Validation Loss: 0.3393, Validation Accuracy: 0.8542
# Epoch [32/300] - Train Loss: 0.3429, Train Accuracy: 0.8562, Validation Loss: 0.3386, Validation Accuracy: 0.8539
# Epoch [33/300] - Train Loss: 0.3378, Train Accuracy: 0.8584, Validation Loss: 0.3345, Validation Accuracy: 0.8574
# Epoch [34/300] - Train Loss: 0.3386, Train Accuracy: 0.8565, Validation Loss: 0.3503, Validation Accuracy: 0.8519
# Epoch [35/300] - Train Loss: 0.3369, Train Accuracy: 0.8579, Validation Loss: 0.3441, Validation Accuracy: 0.8524
# Epoch [36/300] - Train Loss: 0.3359, Train Accuracy: 0.8589, Validation Loss: 0.3290, Validation Accuracy: 0.8609
# Epoch [37/300] - Train Loss: 0.3357, Train Accuracy: 0.8594, Validation Loss: 0.3340, Validation Accuracy: 0.8549
# Epoch [38/300] - Train Loss: 0.3365, Train Accuracy: 0.8580, Validation Loss: 0.3334, Validation Accuracy: 0.8591
# Epoch [39/300] - Train Loss: 0.3325, Train Accuracy: 0.8598, Validation Loss: 0.3357, Validation Accuracy: 0.8528
# Epoch [40/300] - Train Loss: 0.3343, Train Accuracy: 0.8603, Validation Loss: 0.3352, Validation Accuracy: 0.8554
# Epoch [41/300] - Train Loss: 0.3340, Train Accuracy: 0.8587, Validation Loss: 0.3469, Validation Accuracy: 0.8529
# Epoch [42/300] - Train Loss: 0.3320, Train Accuracy: 0.8599, Validation Loss: 0.3342, Validation Accuracy: 0.8585
# Epoch [43/300] - Train Loss: 0.3307, Train Accuracy: 0.8617, Validation Loss: 0.3261, Validation Accuracy: 0.8615
# Epoch [44/300] - Train Loss: 0.3291, Train Accuracy: 0.8609, Validation Loss: 0.3320, Validation Accuracy: 0.8571
# Epoch [45/300] - Train Loss: 0.3294, Train Accuracy: 0.8613, Validation Loss: 0.3376, Validation Accuracy: 0.8569
# Epoch [46/300] - Train Loss: 0.3267, Train Accuracy: 0.8616, Validation Loss: 0.3326, Validation Accuracy: 0.8595
# Epoch [47/300] - Train Loss: 0.3280, Train Accuracy: 0.8611, Validation Loss: 0.3317, Validation Accuracy: 0.8573
# Epoch [48/300] - Train Loss: 0.3258, Train Accuracy: 0.8627, Validation Loss: 0.3323, Validation Accuracy: 0.8585
# Epoch [49/300] - Train Loss: 0.3240, Train Accuracy: 0.8632, Validation Loss: 0.3303, Validation Accuracy: 0.8569
# Epoch [50/300] - Train Loss: 0.3253, Train Accuracy: 0.8632, Validation Loss: 0.3292, Validation Accuracy: 0.8585
# Epoch [51/300] - Train Loss: 0.3239, Train Accuracy: 0.8646, Validation Loss: 0.3338, Validation Accuracy: 0.8575
# Epoch [52/300] - Train Loss: 0.3255, Train Accuracy: 0.8638, Validation Loss: 0.3267, Validation Accuracy: 0.8576
# Epoch [53/300] - Train Loss: 0.3217, Train Accuracy: 0.8646, Validation Loss: 0.3352, Validation Accuracy: 0.8593
# Epoch [54/300] - Train Loss: 0.3212, Train Accuracy: 0.8649, Validation Loss: 0.3337, Validation Accuracy: 0.8559
# Epoch [55/300] - Train Loss: 0.3221, Train Accuracy: 0.8657, Validation Loss: 0.3319, Validation Accuracy: 0.8549
# Epoch [56/300] - Train Loss: 0.3193, Train Accuracy: 0.8656, Validation Loss: 0.3292, Validation Accuracy: 0.8614
# Epoch [57/300] - Train Loss: 0.3168, Train Accuracy: 0.8661, Validation Loss: 0.3359, Validation Accuracy: 0.8554
# Epoch [58/300] - Train Loss: 0.3210, Train Accuracy: 0.8652, Validation Loss: 0.3271, Validation Accuracy: 0.8621
# Epoch [59/300] - Train Loss: 0.3182, Train Accuracy: 0.8667, Validation Loss: 0.3264, Validation Accuracy: 0.8614
# Epoch [60/300] - Train Loss: 0.3183, Train Accuracy: 0.8662, Validation Loss: 0.3334, Validation Accuracy: 0.8583
# Epoch [61/300] - Train Loss: 0.3168, Train Accuracy: 0.8667, Validation Loss: 0.3437, Validation Accuracy: 0.8520
# Epoch [62/300] - Train Loss: 0.3161, Train Accuracy: 0.8671, Validation Loss: 0.3254, Validation Accuracy: 0.8607
# Epoch [63/300] - Train Loss: 0.3155, Train Accuracy: 0.8674, Validation Loss: 0.3323, Validation Accuracy: 0.8583
# Epoch [64/300] - Train Loss: 0.3144, Train Accuracy: 0.8674, Validation Loss: 0.3325, Validation Accuracy: 0.8558
# Epoch [65/300] - Train Loss: 0.3138, Train Accuracy: 0.8680, Validation Loss: 0.3228, Validation Accuracy: 0.8621
# Epoch [66/300] - Train Loss: 0.3126, Train Accuracy: 0.8687, Validation Loss: 0.3291, Validation Accuracy: 0.8622
# Epoch [67/300] - Train Loss: 0.3112, Train Accuracy: 0.8689, Validation Loss: 0.3262, Validation Accuracy: 0.8603
# Epoch [68/300] - Train Loss: 0.3132, Train Accuracy: 0.8692, Validation Loss: 0.3264, Validation Accuracy: 0.8586
# Epoch [69/300] - Train Loss: 0.3101, Train Accuracy: 0.8687, Validation Loss: 0.3256, Validation Accuracy: 0.8599
# Epoch [70/300] - Train Loss: 0.3102, Train Accuracy: 0.8693, Validation Loss: 0.3249, Validation Accuracy: 0.8631
# Epoch [71/300] - Train Loss: 0.3099, Train Accuracy: 0.8694, Validation Loss: 0.3292, Validation Accuracy: 0.8580
# Epoch [72/300] - Train Loss: 0.3092, Train Accuracy: 0.8688, Validation Loss: 0.3322, Validation Accuracy: 0.8592
# Epoch [73/300] - Train Loss: 0.3077, Train Accuracy: 0.8707, Validation Loss: 0.3337, Validation Accuracy: 0.8579
# Epoch [74/300] - Train Loss: 0.3069, Train Accuracy: 0.8711, Validation Loss: 0.3249, Validation Accuracy: 0.8597
# Epoch [75/300] - Train Loss: 0.3065, Train Accuracy: 0.8714, Validation Loss: 0.3224, Validation Accuracy: 0.8615
# Epoch [76/300] - Train Loss: 0.3053, Train Accuracy: 0.8718, Validation Loss: 0.3254, Validation Accuracy: 0.8605
# Epoch [77/300] - Train Loss: 0.3050, Train Accuracy: 0.8717, Validation Loss: 0.3272, Validation Accuracy: 0.8608
# Epoch [78/300] - Train Loss: 0.3038, Train Accuracy: 0.8723, Validation Loss: 0.3402, Validation Accuracy: 0.8567
# Epoch [79/300] - Train Loss: 0.3042, Train Accuracy: 0.8714, Validation Loss: 0.3209, Validation Accuracy: 0.8616
# Epoch [80/300] - Train Loss: 0.3036, Train Accuracy: 0.8712, Validation Loss: 0.3187, Validation Accuracy: 0.8651
# Epoch [81/300] - Train Loss: 0.3040, Train Accuracy: 0.8718, Validation Loss: 0.3229, Validation Accuracy: 0.8634
# Epoch [82/300] - Train Loss: 0.3036, Train Accuracy: 0.8721, Validation Loss: 0.3280, Validation Accuracy: 0.8601
# Epoch [83/300] - Train Loss: 0.3010, Train Accuracy: 0.8739, Validation Loss: 0.3222, Validation Accuracy: 0.8607
# Epoch [84/300] - Train Loss: 0.3015, Train Accuracy: 0.8732, Validation Loss: 0.3222, Validation Accuracy: 0.8638
# Epoch [85/300] - Train Loss: 0.2992, Train Accuracy: 0.8738, Validation Loss: 0.3230, Validation Accuracy: 0.8633
# Epoch [86/300] - Train Loss: 0.2980, Train Accuracy: 0.8741, Validation Loss: 0.3250, Validation Accuracy: 0.8611
# Epoch [87/300] - Train Loss: 0.2997, Train Accuracy: 0.8740, Validation Loss: 0.3233, Validation Accuracy: 0.8614
# Epoch [88/300] - Train Loss: 0.2974, Train Accuracy: 0.8740, Validation Loss: 0.3313, Validation Accuracy: 0.8609
# Epoch [89/300] - Train Loss: 0.2960, Train Accuracy: 0.8755, Validation Loss: 0.3278, Validation Accuracy: 0.8617
# Epoch [90/300] - Train Loss: 0.2962, Train Accuracy: 0.8750, Validation Loss: 0.3234, Validation Accuracy: 0.8638
# Epoch [91/300] - Train Loss: 0.2960, Train Accuracy: 0.8750, Validation Loss: 0.3286, Validation Accuracy: 0.8598
# Epoch [92/300] - Train Loss: 0.2959, Train Accuracy: 0.8745, Validation Loss: 0.3240, Validation Accuracy: 0.8654
# Epoch [93/300] - Train Loss: 0.2927, Train Accuracy: 0.8767, Validation Loss: 0.3238, Validation Accuracy: 0.8607
# Epoch [94/300] - Train Loss: 0.2928, Train Accuracy: 0.8764, Validation Loss: 0.3323, Validation Accuracy: 0.8603
# Epoch [95/300] - Train Loss: 0.2927, Train Accuracy: 0.8772, Validation Loss: 0.3438, Validation Accuracy: 0.8555
# Epoch [96/300] - Train Loss: 0.2918, Train Accuracy: 0.8771, Validation Loss: 0.3313, Validation Accuracy: 0.8583
# Epoch [97/300] - Train Loss: 0.2918, Train Accuracy: 0.8773, Validation Loss: 0.3248, Validation Accuracy: 0.8641
# Epoch [98/300] - Train Loss: 0.2902, Train Accuracy: 0.8768, Validation Loss: 0.3226, Validation Accuracy: 0.8647
# Epoch [99/300] - Train Loss: 0.2898, Train Accuracy: 0.8781, Validation Loss: 0.3272, Validation Accuracy: 0.8619
# Epoch [100/300] - Train Loss: 0.2897, Train Accuracy: 0.8782, Validation Loss: 0.3293, Validation Accuracy: 0.8606
# Epoch [101/300] - Train Loss: 0.2877, Train Accuracy: 0.8791, Validation Loss: 0.3291, Validation Accuracy: 0.8639
# Epoch [102/300] - Train Loss: 0.2879, Train Accuracy: 0.8785, Validation Loss: 0.3267, Validation Accuracy: 0.8623
# Epoch [103/300] - Train Loss: 0.2873, Train Accuracy: 0.8782, Validation Loss: 0.3305, Validation Accuracy: 0.8631
# Epoch [104/300] - Train Loss: 0.2865, Train Accuracy: 0.8793, Validation Loss: 0.3261, Validation Accuracy: 0.8637
# Epoch [105/300] - Train Loss: 0.2859, Train Accuracy: 0.8799, Validation Loss: 0.3362, Validation Accuracy: 0.8597
# Epoch [106/300] - Train Loss: 0.2857, Train Accuracy: 0.8787, Validation Loss: 0.3298, Validation Accuracy: 0.8611
# Epoch [107/300] - Train Loss: 0.2837, Train Accuracy: 0.8805, Validation Loss: 0.3285, Validation Accuracy: 0.8638
# Epoch [108/300] - Train Loss: 0.2841, Train Accuracy: 0.8812, Validation Loss: 0.3300, Validation Accuracy: 0.8605
# Epoch [109/300] - Train Loss: 0.2835, Train Accuracy: 0.8802, Validation Loss: 0.3328, Validation Accuracy: 0.8615
# Early stopping at epoch 110

# %% [markdown]
# #### 4. Testing the Model

# %%
torch.cuda.empty_cache()

# Set the model to evaluation mode
model.load_state_dict(torch.load('./Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Model.pth', map_location=device))

model.eval()
y_test_pred = torch.empty(0).to(device)
print('\n')
# Generate predictions
with torch.no_grad():
    for pf, images, labels in test_loader:
        pf = pf.to(device)
        images = images.to(device)
        labels = labels.to(device)
        pred = model(pf, images)

        y_test_pred = F.softmax(torch.cat((y_test_pred, pred), dim=0))

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(3,3)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_CM.png")
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 torch.cuda.empty_cache()
#       3 # Set the model to evaluation mode
# ----> 4 model.load_state_dict(torch.load('./Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Model.pth', map_location=device))
#       6 model.eval()
#       7 y_test_pred = torch.empty(0).to(device)
#
# NameError: name 'model' is not defined

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 1405475

# %% [markdown]
# ## Result Analysis

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)

zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.1,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1111111, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)

class SGData(Dataset):
    def __init__(self, x1, x2, y, transform=None):
        self.n_samples = x2.shape[0]
        self.x1 = torch.tensor(x1, dtype=torch.float32)
        self.x2 = torch.tensor(x2, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs_pf, inputs_imgs, targets = self.x1[i], self.x2[i], self.y[i]
        
        if self.transform:
            inputs_pf = inputs_pf
            inputs_imgs = self.transform(inputs_imgs)

        return inputs_pf, inputs_imgs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
train_dataset = SGData(dnnx_train, X_train, y_train, transform=None)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=False, num_workers=8)
val_dataset = SGData(dnnx_val, X_val, y_val, transform=None)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False, num_workers=4)
test_dataset = SGData(dnnx_test, X_test, y_test, transform=None)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=4)
# Out:
# ['GALAXY' 'QSO' 'STAR']
#
#
# The shape of the Train data is: (119996, 5, 32, 32)
# The shape of the Validation data is: (15000, 5, 32, 32)
# The shape of the Test data is: (15000, 5, 32, 32)

# %%
model.load_state_dict(torch.load('./Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_Model.pth', map_location=device))

def get_preds(loader):
    model.eval()
    all_preds = []

    with torch.no_grad():
        for pf, images, labels in loader:
            pf = pf.to(device)
            images = images.to(device)
            pred = model(pf, images)
            all_preds.append(pred.cpu())

    all_preds = torch.cat(all_preds, dim=0).numpy()
    pred_labels = all_preds.argmax(axis=1)
    return all_preds, pred_labels

preds_train, y_train_pred = get_preds(train_loader)
print(get_metrics(y_train_pred, y_train, label_strings))
print('\n')
preds_val, y_val_pred = get_preds(val_loader)
print(get_metrics(y_val_pred, y_val, label_strings))
print('\n')
preds_test, y_test_pred = get_preds(test_loader)
print(get_metrics(y_test_pred, y_test, label_strings))
# Out:
# Identified 106338 correct labels out of 119996 labels
# Accuracy: 0.8861795393179772
# Precision: 0.8863746114532712
# Recall: 0.8860674996499305
# F1 Score: 0.8861406458606277
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[38131  1388   615]
#  [ 1274 34302  4416]
#  [  699  5266 33905]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     40134
#            1       0.84      0.86      0.85     39992
#            2       0.87      0.85      0.86     39870
#
#     accuracy                           0.89    119996
#    macro avg       0.89      0.89      0.89    119996
# weighted avg       0.89      0.89      0.89    119996
#
# (array([     0,      1,      2, ..., 119992, 119993, 119994]), 0.8861795393179772, 0.8863746114532712, 0.8860674996499305, array([[38131,  1388,   615],
#        [ 1274, 34302,  4416],
#        [  699,  5266, 33905]]), '              precision    recall  f1-score   support\n\n           0       0.95      0.95      0.95     40134\n           1       0.84      0.86      0.85     39992\n           2       0.87      0.85      0.86     39870\n\n    accuracy                           0.89    119996\n   macro avg       0.89      0.89      0.89    119996\nweighted avg       0.89      0.89      0.89    119996\n')
#
#
# Identified 13028 correct labels out of 15000 labels
# Accuracy: 0.8685333333333334
# Precision: 0.8691051070303347
# Recall: 0.8688744451792766
# F1 Score: 0.8688645879275328
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[4638  208  110]
#  [ 184 4158  607]
#  [ 125  738 4232]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4956
#            1       0.81      0.84      0.83      4949
#            2       0.86      0.83      0.84      5095
#
#     accuracy                           0.87     15000
#    macro avg       0.87      0.87      0.87     15000
# weighted avg       0.87      0.87      0.87     15000
#
# (array([    0,     1,     4, ..., 14997, 14998, 14999]), 0.8685333333333334, 0.8691051070303347, 0.8688744451792766, array([[4638,  208,  110],
#        [ 184, 4158,  607],
#        [ 125,  738, 4232]]), '              precision    recall  f1-score   support\n\n           0       0.94      0.94      0.94      4956\n           1       0.81      0.84      0.83      4949\n           2       0.86      0.83      0.84      5095\n\n    accuracy                           0.87     15000\n   macro avg       0.87      0.87      0.87     15000\nweighted avg       0.87      0.87      0.87     15000\n')
#
#
# Identified 12975 correct labels out of 15000 labels
# Accuracy: 0.865
# Precision: 0.8657803620157346
# Recall: 0.8656791684728696
# F1 Score: 0.8656763957929089
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[4622  200   88]
#  [ 188 4193  678]
#  [ 114  757 4160]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4910
#            1       0.81      0.83      0.82      5059
#            2       0.84      0.83      0.84      5031
#
#     accuracy                           0.86     15000
#    macro avg       0.87      0.87      0.87     15000
# weighted avg       0.87      0.86      0.86     15000
#
# (array([    0,     2,     3, ..., 14995, 14996, 14998]), 0.865, 0.8657803620157346, 0.8656791684728696, array([[4622,  200,   88],
#        [ 188, 4193,  678],
#        [ 114,  757, 4160]]), '              precision    recall  f1-score   support\n\n           0       0.94      0.94      0.94      4910\n           1       0.81      0.83      0.82      5059\n           2       0.84      0.83      0.84      5031\n\n    accuracy                           0.86     15000\n   macro avg       0.87      0.87      0.87     15000\nweighted avg       0.87      0.86      0.86     15000\n')

# %%
df = pd.read_csv("/scratch/srinadb/Foundation/Dataset/Experiment2/photofeatures_exp2.csv",index_col=0)

df.loc[objlist_train, ["set"]] = "TRAIN"
df.loc[objlist_val, ["set"]] = "VALIDATION"
df.loc[objlist_test, ["set"]] = "TEST"

df.loc[objlist_train, ["pred_class"]] = label_strings[preds_train.argmax(axis=1)]
df.loc[objlist_val, ["pred_class"]] = label_strings[preds_val.argmax(axis=1)]
df.loc[objlist_test, ["pred_class"]] = label_strings[preds_test.argmax(axis=1)]

pgal_train = preds_train[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_train = preds_train[:,np.where(label_strings=="STAR")[0][0]]
pqso_train = preds_train[:,np.where(label_strings=="QSO")[0][0]]

pgal_val = preds_val[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_val = preds_val[:,np.where(label_strings=="STAR")[0][0]]
pqso_val = preds_val[:,np.where(label_strings=="QSO")[0][0]]

pgal_test = preds_test[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_test = preds_test[:,np.where(label_strings=="STAR")[0][0]]
pqso_test = preds_test[:,np.where(label_strings=="QSO")[0][0]]


df.loc[objlist_train, ["prob_gal"]] = pgal_train
df.loc[objlist_train, ["prob_star"]] = pstar_train
df.loc[objlist_train, ["prob_qso"]] = pqso_train

df.loc[objlist_val, ["prob_gal"]] = pgal_val
df.loc[objlist_val, ["prob_star"]] = pstar_val
df.loc[objlist_val, ["prob_qso"]] = pqso_val

df.loc[objlist_test, ["prob_gal"]] = pgal_test
df.loc[objlist_test, ["prob_star"]] = pstar_test
df.loc[objlist_test, ["prob_qso"]] = pqso_test
df.to_csv("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_results_exp2.csv")

# %%
sns.set_palette("tab10")
df = pd.read_csv("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_results_exp2.csv")

subdflist = []

bin_size = 0.1
lower_bin_list = np.arange(20,23,bin_size)
bad_lower_bin=[]
acclist = []
f1list = []
reportlist = []
num_samplelist = []
starmaglist = []
galmaglist = []
qsomaglist = []

for lower_bin in lower_bin_list:
#     print(f"******************** {lower_bin} < r <= {lower_bin+bin_size} ********************")
    subdf = df[(
        ((df["dered_r"]+df["extinction_r"]) > lower_bin) & 
        ((df["dered_r"]+df["extinction_r"]) <= lower_bin+bin_size)
    )]
    # Choose equal number of stars, galaxies and qsos
    min_num = subdf["class"].value_counts().min()
    if min_num < 50:
        bad_lower_bin.append(lower_bin)
        continue
    s1 = subdf[subdf["class"]=="GALAXY"].sample(n=min_num)
    galmaglist.append((s1["dered_r"]+s1["extinction_r"]).to_numpy())
    s2 = subdf[subdf["class"]=="STAR"].sample(n=min_num)
    starmaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    s3 = subdf[subdf["class"]=="QSO"].sample(n=min_num)
    qsomaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    num_samplelist.append(min_num)
    subdf = pd.concat([s1,s2,s3])
    subdflist.append(subdf)
    
    accuracy = metrics.accuracy_score(subdf["class"], subdf["pred_class"])
    f1score = metrics.f1_score(subdf["class"], subdf["pred_class"],average='macro')
    report = metrics.classification_report(subdf["class"], subdf["pred_class"],output_dict=True)
    reportlist.append(report)
    acclist.append(accuracy)
    f1list.append(f1score)
    
bad_lower_bin = np.array(bad_lower_bin)
lower_bin_list = lower_bin_list[~np.in1d(lower_bin_list,bad_lower_bin)]
# elems in lower_bin_list not in bad_lower_bin

galmaglist = np.concatenate(galmaglist)

starmaglist = np.concatenate(starmaglist)

qsomaglist = np.concatenate(qsomaglist)
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, xerr=bin_size/2, fmt=" ",color="black",label="Bin")
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, yerr=0.01*100,fmt=".",color="red",label="Accuracy")
# plt.errorbar(lower_bin_list+bin_size/2, f1list, yerr=0.01,label="F1 Score")
plt.legend()
plt.title("Star-Galaxy-QSO")
plt.xlabel("r magnitude bins")
plt.ylabel("Accuracy Score (%)")
plt.savefig("Trained_Models/Experiment2/SGQ/EX2_SGQ_MargFormer_V2_FAINT_SG.pdf")

# %%
subdfs = pd.concat(subdflist)
subdfs["r"]=subdfs["dered_r"]+subdfs["extinction_r"]
gal_recall_list = []
gal_precision_list = []
star_recall_list = []
star_precision_list = []
qso_precision_list = []
qso_recall_list = []
for r in reportlist:
    gal_recall_list.append(r["GALAXY"]["recall"])
    gal_precision_list.append(r["GALAXY"]["precision"])
    star_recall_list.append(r["STAR"]["recall"])
    star_precision_list.append(r["STAR"]["precision"])
    qso_recall_list.append(r["QSO"]["recall"])
    qso_precision_list.append(r["QSO"]["precision"])
    
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1,sharex=True, figsize=(8,18))

galcolor = sns.color_palette("tab10")[1]
starcolor = sns.color_palette("tab10")[2]
qsocolor = sns.color_palette("tab10")[0]
acccolor = sns.color_palette("tab10")[3]
f1color = sns.color_palette("tab10")[4]

dyfit = 0.01
x_ax = lower_bin_list+bin_size/2


d1 = subdfs[subdfs["class"]=="GALAXY"]["r"]
d2 = subdfs[subdfs["class"]=="STAR"]["r"]
d3 = subdfs[subdfs["class"]=="QSO"]["r"]

ax1.hist([d1, d2, d3], color=[galcolor,starcolor, qsocolor],
         alpha=0.8, label=["GALAXY","STAR","QSO"],bins=len(lower_bin_list))
ax1.set_ylabel("Count")

ax1.legend()


y_ax1 = np.array(gal_precision_list)
y_ax2 = np.array(star_precision_list)
y_ax3 = np.array(qso_precision_list)

ax2.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Precision",color=galcolor)
ax2.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax2.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Precision",color=starcolor)
ax2.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
                 color=sns.color_palette("pastel")[2], alpha=0.3)
ax2.errorbar(x_ax, y_ax3*100,fmt="-o", ms=4, label="QSO Precision",color=qsocolor)
ax2.fill_between(x_ax, y_ax3*100 - dyfit*100, y_ax3*100 + dyfit*100,
                 color=sns.color_palette("pastel")[0], alpha=0.3)
ax2.set_ylabel("Precision (%)")
ax2.legend()

y_ax1 = np.array(gal_recall_list)
y_ax2 = np.array(star_recall_list)
y_ax3 = np.array(qso_precision_list)

ax3.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Recall",color=galcolor)
ax3.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax3.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Recall",color=starcolor)
ax3.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
             color=sns.color_palette("pastel")[2], alpha=0.3)
ax3.errorbar(x_ax, y_ax3*100,fmt="-o", ms=4, label="QSO Recall",color=qsocolor)
ax3.fill_between(x_ax, y_ax3*100 - dyfit*100, y_ax3*100 + dyfit*100,
             color=sns.color_palette("pastel")[0], alpha=0.3)
ax3.set_ylabel("Recall (%)")
ax3.legend()



y_ax1 = np.array(acclist)
y_ax2 = np.array(f1list)
ax4.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Accuracy",color=acccolor)
# ax4.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="F1 Score",color=f1color)
ax4.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[3], alpha=0.3)
ax4.set_ylabel("Accuracy Score (%)")
ax4.legend()

plt.xlabel("r magnitude bins")


# plt.suptitle("Star-Galaxy-QSO")
plt.savefig("Trained_Models/Experiment2/SGQ/EX2_SGQ_v2Set.pdf")
plt.show()
